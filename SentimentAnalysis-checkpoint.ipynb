# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\atmiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

sentances = [
    "It's an Amazing Product , It's Worth It.",
    "This Product Is not good , It's not Worth It.",
    "This is Okay Product"
]

for text in sentances:
    scores = analyzer.polarity_scores(text)
    print(text,'--->',scores)
# Out:
# It's an Amazing Product , It's Worth It. ---> {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
# This Product Is not good , It's not Worth It. ---> {'neg': 0.368, 'neu': 0.632, 'pos': 0.0, 'compound': -0.4717}
# This is Okay Product ---> {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.2263}

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

audio_file = "sample.wav"
y,sr = librosa.load(audio_file)

plt.figure(figsize=(10,6))
librosa.display.waveshow(y,sr=sr)
plt.title("Audio Wave")
plt.xlabel("Time")
plt.ylabel("Volume")
# Out:
# Text(76.22222222222221, 0.5, 'Volume')
